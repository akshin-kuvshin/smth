# %% [markdown]
# # Investor - Flow of Funds - US

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/rgrp for sharing the dataset.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
called = pd.read_csv('https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv')
called
# Out:
#            Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0    2011-10-05         -4002          -4499.0           497 -1354.0
# 1    2011-10-12         -7397          -5842.0         -1555   512.0
# 2    2011-10-19         -3292          -3466.0           174  1399.0
# 3    2011-10-26         -3696          -2998.0          -698  2631.0
# 4    2011-12-07         -7956          -5761.0         -2196  1089.0
# ..          ...           ...              ...           ...     ...
# 154  2024-12-04         27170              NaN         22014     NaN
# 155  2024-12-11         36551              NaN         28883     NaN
# 156  2024-12-18         23053              NaN         27124     NaN
# 157  2024-12-24         35211              NaN         36142     NaN
# 158  2024-12-31         26027              NaN         21578     NaN
#
#      Total Bond  Taxable Bond  Municipal Bond    Total
# 0         -5828       -6258.0             430 -11184.0
# ...

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
called = called.set_index('Date')
called
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2011-10-05         -4002          -4499.0           497 -1354.0       -5828
# 2011-10-12         -7397          -5842.0         -1555   512.0        3954
# 2011-10-19         -3292          -3466.0           174  1399.0        5652
# 2011-10-26         -3696          -2998.0          -698  2631.0        4910
# 2011-12-07         -7956          -5761.0         -2196  1089.0        3523
# ...                  ...              ...           ...     ...         ...
# 2024-12-04         27170              NaN         22014     NaN       22510
# 2024-12-11         36551              NaN         28883     NaN       29251
# 2024-12-18         23053              NaN         27124     NaN       20767
# 2024-12-24         35211              NaN         36142     NaN       32529
# 2024-12-31         26027              NaN         21578     NaN       19932
#
#             Taxable Bond  Municipal Bond    Total
# ...

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
called.index.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %%
called.index = pd.to_datetime(called.index)
called.index.dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %%
deltas = pd.Series([called.index[i + 1] - called.index[i] for i in range(len(called) - 1)])
freq = deltas.value_counts().index[0]
print(f'Frequency is approximately {freq}')
# Out:
# Frequency is approximately 7 days 00:00:00

# %% [markdown]
# ### Step 8.  Change the frequency to monthly, sum the values and assign it to monthly.

# %%
criteria = called.index \
                        .map(lambda date: str(date.year) + '-' + str(date.month))
monthly = called.groupby(by=criteria, as_index=True) \
                           .agg('sum')
monthly.index = pd.to_datetime(monthly.index)
monthly
# Out:
#             Total Equity  Domestic Equity  World Equity   Hybrid  Total Bond  \
# Date
# 2011-10-01        -18387         -16805.0         -1582   3188.0        8688
# 2011-12-01        -23657         -16659.0         -6999   2395.0       13817
# 2012-12-01        -23929         -22012.0         -1915    785.0        9828
# 2013-12-01          8052          -5562.0         13615   4180.0      -24460
# 2014-12-01        -17011         -15124.0         -1887  -6141.0      -14400
# 2015-12-01        -36337         -25116.0        -11221 -12474.0      -28678
# 2017-01-01        -16148         -16362.0           214  -3621.0       14983
# 2017-12-01        -35122         -38565.0          3443  -6893.0       11175
# 2019-01-01            97           1372.0         -1275  -5665.0       -1184
# 2019-12-01        -58297         -50202.0         -8095  -5209.0       38491
# 2020-12-01        -66618         -40387.0        -26231  -2972.0       60423
# ...

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
# i don't have this problem

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %%
criteria = monthly.index \
                         .map(lambda date: str(date.year))
yearly = monthly.groupby(by=criteria, as_index=True) \
                           .agg('sum')
yearly.index = pd.to_datetime(yearly.index)
yearly
# Out:
#             Total Equity  Domestic Equity  World Equity   Hybrid  Total Bond  \
# Date
# 2011-01-01        -42044         -33464.0         -8581   5583.0       22505
# 2012-01-01        -23929         -22012.0         -1915    785.0        9828
# 2013-01-01          8052          -5562.0         13615   4180.0      -24460
# 2014-01-01        -17011         -15124.0         -1887  -6141.0      -14400
# 2015-01-01        -36337         -25116.0        -11221 -12474.0      -28678
# 2017-01-01        -51270         -54927.0          3657 -10514.0       26158
# 2019-01-01        -58200         -48830.0         -9370 -10874.0       37307
# 2020-01-01        -66618         -40387.0        -26231  -2972.0       60423
# 2022-01-01        303588              0.0        197245      0.0      159480
# 2023-01-01        577206              0.0        383914      0.0      301690
# 2024-01-01        649200              0.0        498263      0.0      437314
#
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
# i don't want
